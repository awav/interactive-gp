# %%
from gpflow.config import set_default_float, default_float
import numpy as np
import interactive_gp

# %%
set_default_float(np.float64)
data = tf.cast(tf.reshape(tf.linspace(-5., 10., 100), [-1, 1]), dtype=default_float())
samples_viewer = interactive_gp.SamplesViewer(data, num_samples=10)
samples_viewer.view()
# Out:
# Column
#     [0] Markdown(str, max_height=25)
#     [1] Markdown(str)
#     [2] Row
#         [0] Spacer(width=25)
#         [1] Column
#             [0] Select(options=[SquaredExponential(channe...], value=SquaredExponential(channel...)
#             [1] WidgetBox(css_classes=['widget-box'])
#                 [0] LaTeX(str, margin=20)
#                 [1] FloatSlider(end=5, name='Variance', start=1e-06, step=0.01, value=1.0)
#                 [2] FloatSlider(end=5, name='Lengthscale', start=1e-06, step=0.01, value=1.0)
#     [3] HoloViews(DynamicMap)
#     [4] Row
#         [0] HoloViews(DynamicMap)
#         [1] HoloViews(DynamicMap)
